# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
# 3           4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016
# 4           5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016
#
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  4314902            Porto Alegre                43
# 1                  2304707                  Granja                23
# 2                  2304400               Fortaleza                23
# 3                  3304557          Rio de Janeiro                33
# 4                  1302603                  Manaus                13
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  ...   Q041  Q042  Q043  \
# 0               RS        24       M              0.0  ...    5.0     A     A
# ...

# %%
list(train)
# Out:
# ['Unnamed: 0',
#  'NU_INSCRICAO',
#  'NU_ANO',
#  'CO_MUNICIPIO_RESIDENCIA',
#  'NO_MUNICIPIO_RESIDENCIA',
#  'CO_UF_RESIDENCIA',
#  'SG_UF_RESIDENCIA',
#  'NU_IDADE',
#  'TP_SEXO',
#  'TP_ESTADO_CIVIL',
#  'TP_COR_RACA',
#  'TP_NACIONALIDADE',
#  'CO_MUNICIPIO_NASCIMENTO',
#  'NO_MUNICIPIO_NASCIMENTO',
#  'CO_UF_NASCIMENTO',
#  'SG_UF_NASCIMENTO',
#  'TP_ST_CONCLUSAO',
#  'TP_ANO_CONCLUIU',
#  'TP_ESCOLA',
#  'TP_ENSINO',
#  'IN_TREINEIRO',
#  'CO_ESCOLA',
#  'CO_MUNICIPIO_ESC',
#  'NO_MUNICIPIO_ESC',
#  'CO_UF_ESC',
#  'SG_UF_ESC',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'TP_LOCALIZACAO_ESC',
#  'TP_SIT_FUNC_ESC',
#  'IN_BAIXA_VISAO',
#  'IN_CEGUEIRA',
#  'IN_SURDEZ',
#  'IN_DEFICIENCIA_AUDITIVA',
#  'IN_SURDO_CEGUEIRA',
#  'IN_DEFICIENCIA_FISICA',
#  'IN_DEFICIENCIA_MENTAL',
#  'IN_DEFICIT_ATENCAO',
#  'IN_DISLEXIA',
#  'IN_DISCALCULIA',
#  'IN_AUTISMO',
#  'IN_VISAO_MONOCULAR',
#  'IN_OUTRA_DEF',
#  'IN_SABATISTA',
#  'IN_GESTANTE',
#  'IN_LACTANTE',
#  'IN_IDOSO',
# ...

# %%
df_notas = train[['NU_INSCRICAO', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']]

# %%
df_notas_2 = train.loc[:,('NU_INSCRICAO', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO')]

# %%
df_notas_2.head()
# Out:
#                                NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  \
# 0  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad       436.3       495.4
# 1  2c3acac4b33ec2b195d77e7c04a2d75727fad723       474.5       544.1
# 2  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568         NaN         NaN
# 3  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe         NaN         NaN
# 4  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268         NaN         NaN
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0       581.2       399.4            520.0
# 1       599.0       459.8            580.0
# 2         NaN         NaN              NaN
# 3         NaN         NaN              NaN
# 4         NaN         NaN              NaN

# %%
df_notas.head()
# Out:
#                                NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  \
# 0  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad       436.3       495.4
# 1  2c3acac4b33ec2b195d77e7c04a2d75727fad723       474.5       544.1
# 2  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568         NaN         NaN
# 3  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe         NaN         NaN
# 4  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268         NaN         NaN
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0       581.2       399.4            520.0
# 1       599.0       459.8            580.0
# 2         NaN         NaN              NaN
# 3         NaN         NaN              NaN
# 4         NaN         NaN              NaN

# %%
df_notas['NOTA_FINAL'] = (df_notas['NU_NOTA_MT']*3 + df_notas['NU_NOTA_CN']*2 + df_notas['NU_NOTA_LC']*1.5 + 
df_notas['NU_NOTA_CH']*1 + df_notas['NU_NOTA_REDACAO']*3) / 10.5
# Out:
# C:\Users\m113624\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_notas.head()
# Out:
#                                NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  \
# 0  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad       436.3       495.4
# 1  2c3acac4b33ec2b195d77e7c04a2d75727fad723       474.5       544.1
# 2  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568         NaN         NaN
# 3  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe         NaN         NaN
# 4  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268         NaN         NaN
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  NOTA_FINAL
# 0       581.2       399.4            520.0  476.000000
# 1       599.0       459.8            580.0  524.857143
# 2         NaN         NaN              NaN         NaN
# 3         NaN         NaN              NaN         NaN
# 4         NaN         NaN              NaN         NaN

# %%
df_notas = df_notas.sort_values(by = 'NOTA_FINAL', ascending=False)

# %%
df_notas
# Out:
#                                    NU_INSCRICAO  NU_NOTA_CN  NU_NOTA_CH  \
# 10801  848daf808904864c1ee5d51545a2539e2dcbe901       744.2       670.3
# 3226   97166da67df0908861a868cf318b277c4bdbb0da       735.9       782.1
# 3682   b733ccac4e5b7c1da0448f1dad7990ec0793b1d2       764.6       689.0
# 9011   78ca18b6fea7ccd3e067b3945cf200f8686209a7       772.3       725.7
# 4755   8588b01c2ff81ad3c9ff31cd89fc094896c4aa69       757.7       748.7
# 12707  19982f867b8f23a829a2f738374770708ec7f263       758.5       673.1
# 6039   17ae668ce9041105883e9db101d614f58d526f66       760.2       726.5
# 10219  3326c76719930f9838bc9ef803fe1b73a1668723       698.6       712.6
# 1509   41489fd85a5d0cb6e397fb5ebcd19d32e9265cb7       702.7       807.0
# 3535   32767c1a152919a1f72fa91afe19bb7c559f2824       722.1       767.2
# 11334  ac5057ba1f029c2c37bc55c82f3ea3e4b8bcb0ce       712.6       711.2
# 10951  7c7c16a3ebd04e3b4a42e086a447a64fc6fa0996       714.6       761.3
# ...

# %%
df_notas_final = df_notas[['NU_INSCRICAO', 'NOTA_FINAL']]

# %%
df_notas_final[:20].to_csv('answer.csv', index=False)
